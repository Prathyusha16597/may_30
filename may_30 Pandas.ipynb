# %%
import pandas as pd
import numpy as np

# %%
li=pd.read_excel("ilearn_access_log.xlsx")
li
# Out:
#        id first_name last_name          last_login  \
# 0     119     Shruti       NaN 2018-02-09 12:37:00
# 1     119     Shruti       NaN 2018-02-09 12:37:00
# 2     119     Shruti       NaN 2018-02-09 12:37:00
# 3     119     Shruti       NaN 2018-02-09 12:37:00
# 4     119     Shruti       NaN 2018-02-09 12:37:00
# ...   ...        ...       ...                 ...
# 1998  386     Swarup         S 2018-05-27 15:59:00
# 1999  386     Swarup         S 2018-05-27 15:59:00
# 2000  386     Swarup         S 2018-05-27 15:59:00
# 2001  386     Swarup         S 2018-05-27 15:59:00
# 2002  386     Swarup         S 2018-05-27 15:59:00
#
#                                                    path           timestamp
# 0                                                     / 2017-10-06 09:09:00
# 1     /courses/oracle-sql/introduction-to-sql-oracle... 2017-10-06 09:09:00
# 2     /courses/informatica/rank-transforamtion-infor... 2017-10-06 09:09:00
# ...

# %%
li1=li[li['path']=='/']
li1
# Out:
#        id first_name last_name          last_login path           timestamp
# 0     119     Shruti       NaN 2018-02-09 12:37:00    / 2017-10-06 09:09:00
# 3     119     Shruti       NaN 2018-02-09 12:37:00    / 2017-10-06 10:25:00
# 4     119     Shruti       NaN 2018-02-09 12:37:00    / 2017-10-10 07:03:00
# 11    119     Shruti       NaN 2018-02-09 12:37:00    / 2017-10-11 13:36:00
# 16    119     Shruti       NaN 2018-02-09 12:37:00    / 2017-10-17 08:47:00
# ...   ...        ...       ...                 ...  ...                 ...
# 1986  385     Nagesh     Kumar 2018-05-25 08:31:00    / 2018-05-25 15:41:00
# 1987  386     Swarup         S 2018-05-27 15:59:00    / 2018-05-25 15:10:00
# 1988  386     Swarup         S 2018-05-27 15:59:00    / 2018-05-25 15:11:00
# 1989  386     Swarup         S 2018-05-27 15:59:00    / 2018-05-27 11:04:00
# 1994  386     Swarup         S 2018-05-27 15:59:00    / 2018-05-27 15:59:00
#
# [376 rows x 6 columns]

# %%
print(li)
# Out:
#        id first_name last_name          last_login  \
# 0     119     Shruti       NaN 2018-02-09 12:37:00
# 1     119     Shruti       NaN 2018-02-09 12:37:00
# 2     119     Shruti       NaN 2018-02-09 12:37:00
# 3     119     Shruti       NaN 2018-02-09 12:37:00
# 4     119     Shruti       NaN 2018-02-09 12:37:00
# ...   ...        ...       ...                 ...
# 1998  386     Swarup         S 2018-05-27 15:59:00
# 1999  386     Swarup         S 2018-05-27 15:59:00
# 2000  386     Swarup         S 2018-05-27 15:59:00
# 2001  386     Swarup         S 2018-05-27 15:59:00
# 2002  386     Swarup         S 2018-05-27 15:59:00
#
#                                                    path           timestamp
# 0                                                     / 2017-10-06 09:09:00
# 1     /courses/oracle-sql/introduction-to-sql-oracle... 2017-10-06 09:09:00
# 2     /courses/informatica/rank-transforamtion-infor... 2017-10-06 09:09:00
# ...

# %%
li1.to_csv("log_reject1.csv")
li1
# Out:
#        id first_name last_name          last_login path           timestamp
# 0     119     Shruti       NaN 2018-02-09 12:37:00    / 2017-10-06 09:09:00
# 3     119     Shruti       NaN 2018-02-09 12:37:00    / 2017-10-06 10:25:00
# 4     119     Shruti       NaN 2018-02-09 12:37:00    / 2017-10-06 10:25:00
# 5     119     Shruti       NaN 2018-02-09 12:37:00    / 2017-10-10 07:03:00
# 12    119     Shruti       NaN 2018-02-09 12:37:00    / 2017-10-11 13:36:00
# ...   ...        ...       ...                 ...  ...                 ...
# 2142  385     Nagesh     Kumar 2018-05-25 08:31:00    / 2018-05-25 15:41:00
# 2143  386     Swarup         S 2018-05-27 15:59:00    / 2018-05-25 15:10:00
# 2144  386     Swarup         S 2018-05-27 15:59:00    / 2018-05-25 15:11:00
# 2145  386     Swarup         S 2018-05-27 15:59:00    / 2018-05-27 11:04:00
# 2151  386     Swarup         S 2018-05-27 15:59:00    / 2018-05-27 15:59:00
#
# [422 rows x 6 columns]

# %%
li[['id','first_name','last_name']]
# Out:
#        id first_name last_name
# 0     119     Shruti       NaN
# 1     119     Shilpa       NaN
# 2     119     Ramesh       NaN
# 3     119   Sinchana       NaN
# 4     119     Irshad       NaN
# ...   ...        ...       ...
# 1998  386        NaN         S
# 1999  386        NaN         S
# 2000  386        NaN         S
# 2001  386        NaN         S
# 2002  386        NaN         S
#
# [2003 rows x 3 columns]

# %%
li[li[['id','first_name','last_name']].duplicated()]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-a439fb73d384> in <module>
# ----> 1 li[li[['id','first_name','last_name']].duplicated()].drop()
#
# E:\Anaconda\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# E:\Anaconda\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4143             axes, _ = self._construct_axes_from_arguments((index, columns), {})
#    4144         else:
# -> 4145             raise ValueError(
#    4146                 "Need to specify at least one of 'labels', 'index' or 'columns'"
#    4147             )
#
# ...

# %%
employee=li[['id','first_name','last_name']].drop_duplicates()

# %%
print(employee)
# Out:
#        id    first_name   last_name
# 0     119        Shruti         NaN
# 57    136        Shilpa           m
# 64    152        Ramesh         NaN
# 130   158      Sinchana         NaN
# 145   159        Irshad         NaN
# 157   229         Geeta           M
# 288   245       Sasmita     Routary
# 320   253         Pooja     Baadkar
# 353   267        Akshay           G
# 358   269      Prasanna   Pattankar
# 380   290       Shruthi           S
# 410   301        Sachin       Kumar
# 664   306        Soumya       Shree
# 767   308         jyoti           n
# 840   310         anita       reddy
# 873   312   rajashekhar           S
# 994   314       Mustafa          SM
# 1103  317        aditya           j
# 1108  320        Subhra           P
# 1121  325         Ramya           b
# 1239  326    sengamalai           P
# 1325  332      Mahadeva       Swamy
# 1341  342       Supriya           K
# 1424  353        Prerna        Purn
# 1503  354        Dhiraj       Kumar
# ...

# %%
employee.to_excel("employee1.xlsx")
employee
# Out:
#        id    first_name   last_name
# 0     119        Shruti         NaN
# 57    136        Shilpa           m
# 64    152        Ramesh         NaN
# 130   158      Sinchana         NaN
# 145   159        Irshad         NaN
# 157   229         Geeta           M
# 288   245       Sasmita     Routary
# 320   253         Pooja     Baadkar
# 353   267        Akshay           G
# 358   269      Prasanna   Pattankar
# 380   290       Shruthi           S
# 410   301        Sachin       Kumar
# 664   306        Soumya       Shree
# 767   308         jyoti           n
# 840   310         anita       reddy
# 873   312   rajashekhar           S
# 994   314       Mustafa          SM
# 1103  317        aditya           j
# 1108  320        Subhra           P
# 1121  325         Ramya           b
# 1239  326    sengamalai           P
# 1325  332      Mahadeva       Swamy
# 1341  342       Supriya           K
# 1424  353        Prerna        Purn
# 1503  354        Dhiraj       Kumar
# ...

# %%
li.drop_duplicates()
# Out:
#        id first_name last_name          last_login  \
# 0     119     Shruti       NaN 2018-02-09 12:37:00
# 1     119     Shruti       NaN 2018-02-09 12:37:00
# 2     119     Shruti       NaN 2018-02-09 12:37:00
# 3     119     Shruti       NaN 2018-02-09 12:37:00
# 4     119     Shruti       NaN 2018-02-09 12:37:00
# ...   ...        ...       ...                 ...
# 1998  386     Swarup         S 2018-05-27 15:59:00
# 1999  386     Swarup         S 2018-05-27 15:59:00
# 2000  386     Swarup         S 2018-05-27 15:59:00
# 2001  386     Swarup         S 2018-05-27 15:59:00
# 2002  386     Swarup         S 2018-05-27 15:59:00
#
#                                                    path           timestamp
# 0                                                     / 2017-10-06 09:09:00
# 1     /courses/oracle-sql/introduction-to-sql-oracle... 2017-10-06 09:09:00
# 2     /courses/informatica/rank-transforamtion-infor... 2017-10-06 09:09:00
# ...

# %%
df=employee.set_index('id')
df
# Out:
#        first_name   last_name
# id
# 119        Shruti         NaN
# 136        Shilpa           m
# 152        Ramesh         NaN
# 158      Sinchana         NaN
# 159        Irshad         NaN
# 229         Geeta           M
# 245       Sasmita     Routary
# 253         Pooja     Baadkar
# 267        Akshay           G
# 269      Prasanna   Pattankar
# 290       Shruthi           S
# 301        Sachin       Kumar
# 306        Soumya       Shree
# 308         jyoti           n
# 310         anita       reddy
# 312   rajashekhar           S
# 314       Mustafa          SM
# 317        aditya           j
# 320        Subhra           P
# 325         Ramya           b
# 326    sengamalai           P
# 332      Mahadeva       Swamy
# 342       Supriya           K
# 353        Prerna        Purn
# 354        Dhiraj       Kumar
# 355       Pramodh      Munnar
# 359        Nithya  Srinivasan
# 360       Kavitha       Nayak
# 362     Niveditha    Kulkarni
# 363         Sapna           S
# ...

# %%
df.to_excel("employee1.xlsx")
df
# Out:
#        first_name   last_name
# id
# 119        Shruti         NaN
# 136        Shilpa           m
# 152        Ramesh         NaN
# 158      Sinchana         NaN
# 159        Irshad         NaN
# 229         Geeta           M
# 245       Sasmita     Routary
# 253         Pooja     Baadkar
# 267        Akshay           G
# 269      Prasanna   Pattankar
# 290       Shruthi           S
# 301        Sachin       Kumar
# 306        Soumya       Shree
# 308         jyoti           n
# 310         anita       reddy
# 312   rajashekhar           S
# 314       Mustafa          SM
# 317        aditya           j
# 320        Subhra           P
# 325         Ramya           b
# 326    sengamalai           P
# 332      Mahadeva       Swamy
# 342       Supriya           K
# 353        Prerna        Purn
# 354        Dhiraj       Kumar
# 355       Pramodh      Munnar
# 359        Nithya  Srinivasan
# 360       Kavitha       Nayak
# 362     Niveditha    Kulkarni
# 363         Sapna           S
# ...

# %%
li[li['path']=='courses']
# Out:
# Empty DataFrame
# Columns: [id, first_name, last_name, last_login, path, timestamp]
# Index: []

# %%
print([li.path !='/'])
# Out:
# [0       False
# 1        True
# 2        True
# 6        True
# 7        True
#         ...
# 1600     True
# 1704     True
# 1709     True
# 1712     True
# 1756     True
# Name: path, Length: 169, dtype: bool]

# %%
li
# Out:
#        id    first_name   last_name          last_login  \
# 0     119        Shruti         NaN 2018-02-09 12:37:00
# 1     119        Shruti         NaN 2018-02-09 12:37:00
# 2     119        Shruti         NaN 2018-02-09 12:37:00
# 6     119        Shruti         NaN 2018-02-09 12:37:00
# 7     119        Shruti         NaN 2018-02-09 12:37:00
# ...   ...           ...         ...                 ...
# 1600  359        Nithya  Srinivasan 2018-05-10 01:51:00
# 1704  363         Sapna           S 2018-05-08 06:47:00
# 1709  363         Sapna           S 2018-05-08 06:47:00
# 1712  363         Sapna           S 2018-05-08 06:47:00
# 1756  375  Nilesh Kumar       Singh 2018-05-26 07:10:00
#
#                                                    path           timestamp
# 0                                                     / 2017-10-06 09:09:00
# 1     /courses/oracle-sql/introduction-to-sql-oracle... 2017-10-06 09:09:00
# ...

# %%
df=pd.DataFrame(li)
df
# Out:
#        id    first_name   last_name          last_login  \
# 0     119        Shruti         NaN 2018-02-09 12:37:00
# 1     119        Shruti         NaN 2018-02-09 12:37:00
# 2     119        Shruti         NaN 2018-02-09 12:37:00
# 6     119        Shruti         NaN 2018-02-09 12:37:00
# 7     119        Shruti         NaN 2018-02-09 12:37:00
# ...   ...           ...         ...                 ...
# 1600  359        Nithya  Srinivasan 2018-05-10 01:51:00
# 1704  363         Sapna           S 2018-05-08 06:47:00
# 1709  363         Sapna           S 2018-05-08 06:47:00
# 1712  363         Sapna           S 2018-05-08 06:47:00
# 1756  375  Nilesh Kumar       Singh 2018-05-26 07:10:00
#
#                                                    path           timestamp
# 0                                                     / 2017-10-06 09:09:00
# 1     /courses/oracle-sql/introduction-to-sql-oracle... 2017-10-06 09:09:00
# ...

# %%
df[df.path !='/']
print(df)
# Out:
#        id    first_name   last_name          last_login  \
# 0     119        Shruti         NaN 2018-02-09 12:37:00
# 1     119        Shruti         NaN 2018-02-09 12:37:00
# 2     119        Shruti         NaN 2018-02-09 12:37:00
# 6     119        Shruti         NaN 2018-02-09 12:37:00
# 7     119        Shruti         NaN 2018-02-09 12:37:00
# ...   ...           ...         ...                 ...
# 1600  359        Nithya  Srinivasan 2018-05-10 01:51:00
# 1704  363         Sapna           S 2018-05-08 06:47:00
# 1709  363         Sapna           S 2018-05-08 06:47:00
# 1712  363         Sapna           S 2018-05-08 06:47:00
# 1756  375  Nilesh Kumar       Singh 2018-05-26 07:10:00
#
#                                                    path           timestamp
# 0                                                     / 2017-10-06 09:09:00
# 1     /courses/oracle-sql/introduction-to-sql-oracle... 2017-10-06 09:09:00
# ...
